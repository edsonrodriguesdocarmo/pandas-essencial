# %% [markdown]
# Converter .csv para .parquet na mesma pasta

# %%
import pandas as pd
from pathlib import Path

source = Path(r'C:\Users\c136468\OneDrive - Caixa Economica Federal\Portal SR Agronegócios - BI SRA\BI GENAG\Painel_SIGA_completo\Painel_SIGA_completo.csv')
dest = source.with_suffix('.parquet')

df = pd.read_csv(source, encoding='cp1252', sep=';')
df.to_parquet(dest, engine='pyarrow', compression='snappy')

# %% [markdown]
# Converter .xlsx para .parquet na mesma pasta

# %%
import pandas as pd
from pathlib import Path

source = Path(r'C:\Users\c136468\OneDrive - Caixa Economica Federal\Portal SR Agronegócios - BI SRA\BI GENAG\Solicitações\Solicitações.xlsx')
dest = source.with_suffix('.parquet')

df = pd.read_excel(source)
df.to_parquet(dest, engine='pyarrow', compression='snappy')

# %%
import pandas as pd

# %%
from pathlib import Path

# %%
import pandas as pd
from pathlib import Path

source = Path(r'C:\Users\c136468\OneDrive - Caixa Economica Federal\O365GRP-simulador_agro - BI_Mercado_MDCR\Base Histórica SICOR - Detalhamento 360 dias\SICOR_OPERACAO_BASICA_ESTADO_2026.gz')
dest = source.with_suffix('.parquet')

df = pd.read_csv(source, compression='gzip', sep=';')
df.to_parquet(dest, engine='pyarrow', compression='snappy')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875626 entries, 0 to 875625
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   #REF_BACEN                 875626 non-null  int64
#  1   NU_ORDEM                   875626 non-null  int64
#  2   CNPJ_IF                    875626 non-null  int64
#  3   DT_EMISSAO                 875626 non-null  datetime64[ns]
#  4   DT_VENCIMENTO              875626 non-null  object
#  5   CD_INST_CREDITO            875626 non-null  int64
#  6   CD_CATEG_EMITENTE          875626 non-null  int64
#  7   CD_FONTE_RECURSO           875626 non-null  int64
#  8   CNPJ_AGENTE_INVEST         7044 non-null    float64
#  9   CD_ESTADO                  875626 non-null  object
#  10  CD_REF_BACEN_INVESTIMENTO  7044 non-null    float64
#  11  CD_TIPO_SEGURO             875626 non-null  int64
#  12  CD_EMPREENDIMENTO          875626 non-null  int64
# ...

# %%
df['DT_EMISSAO'].head(5)
# Out:
# 0   2026-01-02
# 1   2026-01-02
# 2   2026-01-02
# 3   2026-01-02
# 4   2026-01-02
# Name: DT_EMISSAO, dtype: datetime64[ns]

# %%
df['DT_EMISSAO'] = pd.to_datetime(df['DT_EMISSAO'], format='%d/%m/%Y')

# %%
df['DT_VENCIMENTO'] = pd.to_datetime(df['DT_VENCIMENTO'], format='%d/%m/%Y')

# %%
df['CD_ESTADO'] = df['CD_ESTADO'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875626 entries, 0 to 875625
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   #REF_BACEN                 875626 non-null  int64
#  1   NU_ORDEM                   875626 non-null  int64
#  2   CNPJ_IF                    875626 non-null  int64
#  3   DT_EMISSAO                 875626 non-null  datetime64[ns]
#  4   DT_VENCIMENTO              875626 non-null  datetime64[ns]
#  5   CD_INST_CREDITO            875626 non-null  int64
#  6   CD_CATEG_EMITENTE          875626 non-null  int64
#  7   CD_FONTE_RECURSO           875626 non-null  int64
#  8   CNPJ_AGENTE_INVEST         7044 non-null    float64
#  9   CD_ESTADO                  875626 non-null  category
#  10  CD_REF_BACEN_INVESTIMENTO  7044 non-null    float64
#  11  CD_TIPO_SEGURO             875626 non-null  int64
#  12  CD_EMPREENDIMENTO          875626 non-null  int64
# ...

# %%
df['DT_FIM_COLHEITA'] = pd.to_datetime(df['DT_FIM_COLHEITA'], format='%d/%m/%Y')

# %%
df['DT_FIM_PLANTIO'] = pd.to_datetime(df['DT_FIM_PLANTIO'], format='%d/%m/%Y', errors='coerce')

# %%
df['DT_FIM_PLANTIO'].head(100)
# Out:
# 0            NaN
# 1            NaN
# 2     31/07/2026
# 3            NaN
# 4            NaN
#          ...
# 95    10/01/2026
# 96           NaN
# 97           NaN
# 98           NaN
# 99    16/05/2026
# Name: DT_FIM_PLANTIO, Length: 100, dtype: object

# %%
df['DT_INIC_COLHEITA'] = pd.to_datetime(df['DT_INIC_COLHEITA'], format='%d/%m/%Y')
df['DT_INIC_PLANTIO'] = pd.to_datetime(df['DT_INIC_PLANTIO'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875626 entries, 0 to 875625
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   #REF_BACEN                 875626 non-null  int64
#  1   NU_ORDEM                   875626 non-null  int64
#  2   CNPJ_IF                    875626 non-null  int64
#  3   DT_EMISSAO                 875626 non-null  datetime64[ns]
#  4   DT_VENCIMENTO              875626 non-null  datetime64[ns]
#  5   CD_INST_CREDITO            875626 non-null  int64
#  6   CD_CATEG_EMITENTE          875626 non-null  int64
#  7   CD_FONTE_RECURSO           875626 non-null  int64
#  8   CNPJ_AGENTE_INVEST         7044 non-null    float64
#  9   CD_ESTADO                  875626 non-null  category
#  10  CD_REF_BACEN_INVESTIMENTO  7044 non-null    float64
#  11  CD_TIPO_SEGURO             875626 non-null  int64
#  12  CD_EMPREENDIMENTO          875626 non-null  int64
# ...

# %%
df.to_parquet('Sicor_Operacoes_Basica_Estado.parquet', index=False)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875626 entries, 0 to 875625
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   #REF_BACEN                 875626 non-null  int64
#  1   NU_ORDEM                   875626 non-null  int64
#  2   CNPJ_IF                    875626 non-null  int64
#  3   DT_EMISSAO                 875626 non-null  datetime64[ns]
#  4   DT_VENCIMENTO              875626 non-null  datetime64[ns]
#  5   CD_INST_CREDITO            875626 non-null  int64
#  6   CD_CATEG_EMITENTE          875626 non-null  int64
#  7   CD_FONTE_RECURSO           875626 non-null  int64
#  8   CNPJ_AGENTE_INVEST         7044 non-null    float64
#  9   CD_ESTADO                  875626 non-null  category
#  10  CD_REF_BACEN_INVESTIMENTO  7044 non-null    float64
#  11  CD_TIPO_SEGURO             875626 non-null  int64
#  12  CD_EMPREENDIMENTO          875626 non-null  int64
# ...
